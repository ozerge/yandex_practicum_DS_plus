# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Откроем-и-сохраним-файл-данных" data-toc-modified-id="Откроем-и-сохраним-файл-данных-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Откроем и сохраним файл данных</a></span></li><li><span><a href="#Изучим-общую-информацию-о-датафрейме" data-toc-modified-id="Изучим-общую-информацию-о-датафрейме-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Изучим общую информацию о датафрейме</a></span></li><li><span><a href="#Предобработка-данных:" data-toc-modified-id="Предобработка-данных:-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Предобработка данных:</a></span></li><li><span><a href="#Посмотрим-на-корреляцию-данных" data-toc-modified-id="Посмотрим-на-корреляцию-данных-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Посмотрим на корреляцию данных</a></span></li><li><span><a href="#Перевод-категориальных-признаков-в-численные" data-toc-modified-id="Перевод-категориальных-признаков-в-численные-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Перевод категориальных признаков в численные</a></span></li><li><span><a href="#Подготовка-данных-для-машинного-обучения" data-toc-modified-id="Подготовка-данных-для-машинного-обучения-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Подготовка данных для машинного обучения</a></span></li><li><span><a href="#Баланс-классов" data-toc-modified-id="Баланс-классов-1.7"><span class="toc-item-num">1.7&nbsp;&nbsp;</span>Баланс классов</a></span></li><li><span><a href="#Вывод:" data-toc-modified-id="Вывод:-1.8"><span class="toc-item-num">1.8&nbsp;&nbsp;</span>Вывод:</a></span></li></ul></li><li><span><a href="#Исследование-задачи" data-toc-modified-id="Исследование-задачи-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Исследование задачи</a></span><ul class="toc-item"><li><span><a href="#Обучение-моделей-без-учёта-дисбаланса." data-toc-modified-id="Обучение-моделей-без-учёта-дисбаланса.-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Обучение моделей без учёта дисбаланса.</a></span></li><li><span><a href="#Проверим-качество-моделей-без-учёта-дисбаланса." data-toc-modified-id="Проверим-качество-моделей-без-учёта-дисбаланса.-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Проверим качество моделей без учёта дисбаланса.</a></span></li></ul></li><li><span><a href="#Борьба-с-дисбалансом." data-toc-modified-id="Борьба-с-дисбалансом.-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Борьба с дисбалансом.</a></span><ul class="toc-item"><li><span><a href="#Взвешивание-классов." data-toc-modified-id="Взвешивание-классов.-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Взвешивание классов.</a></span></li><li><span><a href="#Увелечение-количества-положительного-класса." data-toc-modified-id="Увелечение-количества-положительного-класса.-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Увелечение количества положительного класса.</a></span></li><li><span><a href="#Уменьшение-количества-отрицательного-класса" data-toc-modified-id="Уменьшение-количества-отрицательного-класса-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Уменьшение количества отрицательного класса</a></span></li><li><span><a href="#Вывод-по-баллансировке" data-toc-modified-id="Вывод-по-баллансировке-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Вывод по баллансировке</a></span></li></ul></li><li><span><a href="#Тестирование-модели" data-toc-modified-id="Тестирование-модели-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Тестирование модели</a></span></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Общий вывод</a></span></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# # Отток клиентов

# %% [markdown]
# Из «Бета-Банка» стали уходить клиенты. Каждый месяц. Немного, но заметно. Банковские маркетологи посчитали: сохранять текущих клиентов дешевле, чем привлекать новых.
#
# Нужно спрогнозировать, уйдёт клиент из банка в ближайшее время или нет. Вам предоставлены исторические данные о поведении клиентов и расторжении договоров с банком.
#
# Постройте модель с предельно большим значением *F1*-меры. Чтобы сдать проект успешно, нужно довести метрику до 0.59. Проверьте *F1*-меру на тестовой выборке самостоятельно.
#
# Дополнительно измеряйте *AUC-ROC*, сравнивайте её значение с *F1*-мерой.
#
# Источник данных: [https://www.kaggle.com/barelydedicated/bank-customer-churn-modeling](https://www.kaggle.com/barelydedicated/bank-customer-churn-modeling)

# %% [markdown]
# # Исходные данные.
#
#
# **Признаки:**
#
# - RowNumber — индекс строки в данных,
# - CustomerId — уникальный идентификатор клиента,
# - Surname — фамилия,
# - CreditScore — кредитный рейтинг,
# - Geography — страна проживания,
# - Gender — пол,
# - Age — возраст,
# - Tenure — количество недвижимости у клиента,
# - Balance — баланс на счёте,
# - NumOfProducts — количество продуктов банка, используемых клиентом,
# - HasCrCard — наличие кредитной карты,
# - IsActiveMember — активность клиента,
# - EstimatedSalary — предполагаемая зарплата.
#
#
# **Целевой признак:**
#
# - Exited — факт ухода клиента.

# %% [markdown]
# ***Цель проекта*** - Построить модель, прогнозирующую уход клиента из банка в ближайшее время или нет, с предельно большим значением F1-меры до 0.59. Проверить F1-меру на тестовой выборке самостоятельно. Дополнительно измерить AUC-ROC, сравнивая её значение с F1-мерой. Задача относится к классу «обучения с учителем», классификация.
#
# ***Последовательность выполнения проекта:***
#
# 1.Изучение файла с данными.
# 2.Предобработка данных.
# 3.Исследование баланса классов, обучение модели без учёта дисбаланса.
# 4.Улучшение качества модели с учетом дисбаланса классов. Лучшая модель.
# 5.Финальное тестирование.

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# ### Откроем и сохраним файл данных

# %% [markdown]
# Импортируем нужные библиотеки

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.dummy import DummyClassifier
from sklearn.metrics import accuracy_score, confusion_matrix,recall_score, precision_score
from sklearn.metrics import f1_score, roc_auc_score, roc_curve
from sklearn.utils import shuffle
#import warnings 
#warnings.filterwarnings("ignore")

# %%
# Открываем и сохраняем файл Churn.csv в датафрейм из директории или по ссылке:
try:
    df_churn = pd.read_csv('/datasets/Churn.csv')
except:
    df_churn = pd.read_csv('https://code.s3.yandex.net/datasets/Churn.csv')

# %% [markdown]
# ### Изучим общую информацию о датафрейме

# %%
# Посмотрим полную информацию датафрейма:  
df_churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           9091 non-null   float64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(3), int64(8), object(3)
# memory usage: 1.1+ MB

# %%
# Выведем первые пять строк датафрейма df_churn:
df_churn.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0     2.0       0.00              1          1               1
# 1     1.0   83807.86              1          0               1
# 2     8.0  159660.80              3          1               0
# 3     1.0       0.00              2          0               0
# 4     2.0  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %% [markdown]
# В датасете 14 столбцов и 10000 записей.
# Привести названия стобцов к стандарту PEP8.
# В столбце `Tenure` есть пропуски, перевести данные в столбце Tenure из типа float в int.
# Избавиться от столбца `RowNumber`(фактически дублирует нумерацию объектов с шагом 1) и столбца `CustomerId`(случайный или последовательный номер, который никак не зависит от действий клиента), а также от столбца `Surname`(имя клиента, признак невлияющий на уход клиента).
# В целевом признаке высокая доля объектов отрицательного класса, то есть в дальнейшем нужно будет увеличить долю объектов положительного класса.

# %% [markdown]
# **Посмотрим на распределение данных:**

# %%
for param in ['CreditScore', 'Age', 'Tenure', 'Balance', 'EstimatedSalary', 'NumOfProducts']:
    fig, ax = plt.subplots(figsize=(8,5))
    sns.histplot(df_churn[param])

# %%
df_churn.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age       Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  9091.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800     4.997690
# std     2886.89568  7.193619e+04     96.653299     10.487806     2.894723
# min        1.00000  1.556570e+07    350.000000     18.000000     0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000     2.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000     5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000     7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000    10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %% [markdown]
# *вывод*
# Из графиков:
# - Кредитный рейтинг обрывается на 850. Возможно это в принципе максимальное значение
# - На удивление кол-во недвижемости распределено равномерно
# - У многих на балансе 0
#
# Из describe видно:
# - Кредитная карта есть у 70%
# - Доля активных клиентов 51%
# - Доля ушедших клиентов в выборке 20%. Явный дисбалланс классов.

# %% [markdown]
# ### Предобработка данных:

# %%
# Избавляемся от столбцов:
df_churn = df_churn.drop(['RowNumber', 'CustomerId', 'Surname'], axis=1)

# %%
# Приведём названия оставшихся столбцов к стандарту PEP8.
df_churn.rename(columns={
    'CreditScore':'credit_score',
    'Geography':'geography',
    'Gender':'gender',
    'Age':'age',
    'Tenure':'tenure', 'Balance':'balance',
    'NumOfProducts':'num_of_products',
    'HasCrCard':'has_cr_card',
    'IsActiveMember':'is_active_member',
    'EstimatedSalary':'estimated_salary',
    'Exited':'exited',
}, inplace=True)

# %%
# Проверяем:
df_churn.head()
# Out:
#    credit_score geography  gender  age  tenure    balance  num_of_products  \
# 0           619    France  Female   42     2.0       0.00                1
# 1           608     Spain  Female   41     1.0   83807.86                1
# 2           502    France  Female   42     8.0  159660.80                3
# 3           699    France  Female   39     1.0       0.00                2
# 4           850     Spain  Female   43     2.0  125510.82                1
#
#    has_cr_card  is_active_member  estimated_salary  exited
# 0            1                 1         101348.88       1
# 1            0                 1         112542.58       0
# 2            1                 0         113931.57       1
# 3            0                 0          93826.63       0
# 4            1                 1          79084.10       0

# %%
# Проверим на дубликаты:
df_churn.duplicated().sum()
# Out:
# 0

# %% [markdown]
# *Явных дубликатов в датасете не наблюдается*

# %%
# Посмотрим на кол-во пропусков в датафрейме:
df_churn.isnull().sum()
# Out:
# credit_score          0
# geography             0
# gender                0
# age                   0
# tenure              909
# balance               0
# num_of_products       0
# has_cr_card           0
# is_active_member      0
# estimated_salary      0
# exited                0
# dtype: int64

# %% [markdown]
# Пропуски в столбце `Tenure` состовляют примерно 10%. Заменим все NaN из столбца Tenure на медианное значение.

# %%
df_churn['tenure'] = df_churn['tenure'].fillna(df_churn['tenure'].median())

# %%
# Переводим данные в столбце 'tenure' в int:
df_churn['tenure'] = df_churn['tenure'].astype('int')

# %%
# Проверяем:
df_churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   credit_score      10000 non-null  int64
#  1   geography         10000 non-null  object
#  2   gender            10000 non-null  object
#  3   age               10000 non-null  int64
#  4   tenure            10000 non-null  int64
#  5   balance           10000 non-null  float64
#  6   num_of_products   10000 non-null  int64
#  7   has_cr_card       10000 non-null  int64
#  8   is_active_member  10000 non-null  int64
#  9   estimated_salary  10000 non-null  float64
#  10  exited            10000 non-null  int64
# dtypes: float64(2), int64(7), object(2)
# memory usage: 859.5+ KB

# %% [markdown]
# *В датафрейме пропусков нет.*

# %% [markdown]
# ### Посмотрим на корреляцию данных

# %%
sns.pairplot(df_churn.sample(frac=0.1, random_state=314159), hue='exited', corner=True, kind='kde')
plt.show()

# %%
df_churn.corr(numeric_only = True)
# Out:
#                   credit_score       age    tenure   balance  num_of_products  \
# credit_score          1.000000 -0.003965 -0.000060  0.006268         0.012238
# age                  -0.003965  1.000000 -0.012606  0.028308        -0.030680
# tenure               -0.000060 -0.012606  1.000000 -0.007535         0.011409
# balance               0.006268  0.028308 -0.007535  1.000000        -0.304180
# num_of_products       0.012238 -0.030680  0.011409 -0.304180         1.000000
# has_cr_card          -0.005458 -0.011721  0.025979 -0.014858         0.003183
# is_active_member      0.025651  0.085472 -0.030681 -0.010084         0.009612
# estimated_salary     -0.001384 -0.007201  0.010049  0.012797         0.014204
# exited               -0.027094  0.285323 -0.015989  0.118533        -0.047820
#
#                   has_cr_card  is_active_member  estimated_salary    exited
# credit_score        -0.005458          0.025651         -0.001384 -0.027094
# ...

# %% [markdown]
# ***вывод***
# На корреляционной матрице мы увидели некоторые явные зависимости:
# - видна сильная корреляция вероятности ухода клиента от его возраста - средний возраст уходящего клиента равен 45 годам, в то время как текущие клиенты имеют средний возраст 35 лет
# - у большей части ушедших клиентов был только один банковский продукт, в то время как у текущих клиентов в среднем два активных продукта
# - уходящие клиенты являются менее активными
# - срок обслуживания клиента, баланс, наличие кредитки, средитная оценка и ожидаемая зарплата почти не влияют на вероятность ухода

# %% [markdown]
# ### Перевод категориальных признаков в численные

# %%
# Посмотрим кол-во уникальных значений в столбце 'geography':
df_churn['geography'].unique()
# Out:
# array(['France', 'Spain', 'Germany'], dtype=object)

# %% [markdown]
# `Geography` — всего 3 уникальных значения 'France', 'Spain', 'Germany' — выполнить преобразование OHE / ordinal encoding.
# `Gender` — значение преобразовать — OHE / ordinal encoding.

# %%
# Данные подготовим методом OHE, что позволит нам использовать разные модели и учесть дамми ловушку:
df_churn_ohe = pd.get_dummies(df_churn, drop_first=True)
df_churn_ohe.head()
# Out:
#    credit_score  age  tenure    balance  num_of_products  has_cr_card  \
# 0           619   42       2       0.00                1            1
# 1           608   41       1   83807.86                1            0
# 2           502   42       8  159660.80                3            1
# 3           699   39       1       0.00                2            0
# 4           850   43       2  125510.82                1            1
#
#    is_active_member  estimated_salary  exited  geography_Germany  \
# 0                 1         101348.88       1                  0
# 1                 1         112542.58       0                  0
# 2                 0         113931.57       1                  0
# 3                 0          93826.63       0                  0
# 4                 1          79084.10       0                  0
#
#    geography_Spain  gender_Male
# 0                0            0
# 1                1            0
# 2                0            0
# ...

# %%
df_churn_ohe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   credit_score       10000 non-null  int64
#  1   age                10000 non-null  int64
#  2   tenure             10000 non-null  int64
#  3   balance            10000 non-null  float64
#  4   num_of_products    10000 non-null  int64
#  5   has_cr_card        10000 non-null  int64
#  6   is_active_member   10000 non-null  int64
#  7   estimated_salary   10000 non-null  float64
#  8   exited             10000 non-null  int64
#  9   geography_Germany  10000 non-null  uint8
#  10  geography_Spain    10000 non-null  uint8
#  11  gender_Male        10000 non-null  uint8
# dtypes: float64(2), int64(7), uint8(3)
# memory usage: 732.5 KB

# %%
# Приведём названия оставшихся столбцов к стандарту PEP8.
df_churn_ohe.rename(columns={
    'geography_Germany':'geography_germany',
    'geography_Spain':'geography_spain',
    'gender_Male':'gender_male'
}, inplace=True)

# %%
# Проверяем:
df_churn_ohe.head()
# Out:
#    credit_score  age  tenure    balance  num_of_products  has_cr_card  \
# 0           619   42       2       0.00                1            1
# 1           608   41       1   83807.86                1            0
# 2           502   42       8  159660.80                3            1
# 3           699   39       1       0.00                2            0
# 4           850   43       2  125510.82                1            1
#
#    is_active_member  estimated_salary  exited  geography_germany  \
# 0                 1         101348.88       1                  0
# 1                 1         112542.58       0                  0
# 2                 0         113931.57       1                  0
# 3                 0          93826.63       0                  0
# 4                 1          79084.10       0                  0
#
#    geography_spain  gender_male
# 0                0            0
# 1                1            0
# 2                0            0
# ...

# %% [markdown]
# ### Подготовка данных для машинного обучения

# %%
# Создаем переменные для признаков и целевого признака:
features = df_churn_ohe.drop(['exited'], axis=1)
target = df_churn_ohe['exited']

# %% [markdown]
# ***Разбиваем данные на три выборки: обучающую, валидационную и тестовую в соотношении 60/20/20***

# %%
features_train, features_tst, target_train, target_tst = train_test_split(features, target,
                                                                          test_size=0.40, random_state=12345670)
features_valid, features_test, target_valid, target_test = train_test_split(features_tst, target_tst,
                                                                            test_size=0.50, random_state=12345670)

# %%
print('Размер обучающей выборки', features_train.shape, target_train.shape)
print('Размер валидационной выборки', features_valid.shape, target_valid.shape)
print('Размер тестовой выборки', features_test.shape, target_test.shape)
# Out:
# Размер обучающей выборки (6000, 11) (6000,)
# Размер валидационной выборки (2000, 11) (2000,)
# Размер тестовой выборки (2000, 11) (2000,)

# %% [markdown]
# ***Масштабируем признаки методом стандартизации.***

# %%
# Фиксируем численные признаки:
numeric = ['credit_score', 'age', 'tenure', 'balance', 'num_of_products', 'estimated_salary']

# %%
# Создаем объект для стандартизации данных:
scaler = StandardScaler()
scaler.fit(features_train[numeric])
# Out:
# StandardScaler()

# %%
# Масштабирование обучающего набора данных:
features_train[numeric] = scaler.transform(features_train[numeric])
features_train.head()
# Out:
#       credit_score       age    tenure   balance  num_of_products  \
# 5764      0.800393 -0.478504 -1.827033  1.735673        -0.907756
# 5203      1.079319 -0.857380 -1.462792  0.537893        -0.907756
# 1970      0.180557  0.184528  1.815377  1.022977        -0.907756
# 1798      0.676425  1.131718 -0.370069  0.177879         2.549266
# 7316      1.492543  1.415875 -1.098551  0.827969        -0.907756
#
#       has_cr_card  is_active_member  estimated_salary  geography_germany  \
# 5764            1                 1          0.033034                  0
# 5203            1                 1         -0.736643                  1
# 1970            1                 0         -0.858488                  0
# 1798            0                 0         -1.643953                  0
# 7316            0                 0         -1.421268                  1
#
#       geography_spain  gender_male
# 5764                0            0
# 5203                0            1
# ...

# %%
# Масштабирование валидационног набора данных:
features_valid[numeric] = scaler.transform(features_valid[numeric])
features_valid.head()
# Out:
#       credit_score       age    tenure   balance  num_of_products  \
# 2831     -0.232668 -0.667942 -1.827033 -1.234139         0.820755
# 1439      1.337584  2.457784  0.722654 -1.234139        -0.907756
# 3613      0.159895 -1.330975  0.358413  1.529055         0.820755
# 3009     -1.007463 -0.762661 -1.462792 -1.234139         0.820755
# 7791     -0.666553 -0.762661  0.358413  1.206221        -0.907756
#
#       has_cr_card  is_active_member  estimated_salary  geography_germany  \
# 2831            0                 0          1.517543                  0
# 1439            1                 1         -0.388410                  0
# 3613            1                 1          0.137165                  1
# 3009            1                 1          1.481499                  0
# 7791            1                 0         -0.014708                  1
#
#       geography_spain  gender_male
# 2831                0            0
# 1439                0            0
# ...

# %%
# Масштабирование тестового набора данных:
features_test[numeric] = scaler.transform(features_test[numeric])
features_test.head()
# Out:
#       credit_score       age    tenure   balance  num_of_products  \
# 8593     -0.397957 -0.289066  0.722654  0.612045        -0.907756
# 4617      1.688824 -1.425694 -0.005828 -1.234139         0.820755
# 9147     -0.129362 -0.383785  1.451136  0.292512        -0.907756
# 2355     -0.821512  0.279247 -1.462792 -1.234139        -0.907756
# 5425     -0.046717  0.468685  1.086895  0.461115         0.820755
#
#       has_cr_card  is_active_member  estimated_salary  geography_germany  \
# 8593            0                 1         -1.003694                  1
# 4617            1                 1          0.989789                  0
# 9147            0                 0          1.205669                  0
# 2355            1                 1         -0.287932                  0
# 5425            0                 0          0.847177                  1
#
#       geography_spain  gender_male
# 8593                0            1
# 4617                0            1
# ...

# %% [markdown]
# ### Баланс классов

# %%
target.value_counts(normalize = 1)
# Out:
# 0    0.7963
# 1    0.2037
# Name: exited, dtype: float64

# %%
# Построим диаграмму баланса классов
target.plot(kind ='hist', bins=3, figsize=(3,4));

# %% [markdown]
# В датасете явный дисбаланс в целевом признаке - отрицательны ответов ≈ 80% , положитительных ≈ 20%.

# %% [markdown]
# ### Вывод:
#
# - В датасете 12 столбцов и 10000 записей.
# - Распределение данных:
#    Из графиков:
#     - Кредитный рейтинг обрывается на 850. Возможно это в принципе максимальное значение.
#     - На удивление кол-во недвижемости распределено равномерно.
#     - У многих на балансе 0.
#     Из describe видно:
#     - Кредитная карта есть у 70%.
#     - Доля активных клиентов 51%.
#     - Доля ушедших клиентов в выборке 20%. Явный дисбалланс классов.
# - На корреляционной матрице мы увидели некоторые явные зависимости:
#     - видна сильная корреляция вероятности ухода клиента от его возраста - средний возраст уходящего клиента равен 45 годам, в то время как текущие клиенты имеют средний возраст 35 лет.
#     - у большей части ушедших клиентов был только один банковский продукт, в то время как у текущих клиентов в среднем два активных продукта.
#     - уходящие клиенты являются менее активными.
#     - срок обслуживания клиента, баланс, наличие кредитки, средитная оценка и ожидаемая зарплата почти не влияют на вероятность ухода.
# - Проверили наш датасет на явные дубликаты. дубликатов нет.
# - Проверили наш датасет на пропуски. Пропуски были обнаруженны в столбце `Tenure` и состовили 10%. Заменили все NaN на медианное значение. преобразовали тип данных в int.
# - Удалили столбец `RowNumber`(фактически дублирует нумерацию объектов с шагом 1) и столбца CustomerId(случайный или последовательный номер, который никак не зависит от действий клиента), а также от столбца Surname(имя клиента, признак невлияющий на уход клиента).
# - Привели наименование столбцов в соответствие с PEP8.
# - Перевели категориальные данные в численные (столбцы `Geography`,`Gender`) методом OHE, что позволит нам использовать разные модели и учесть дамми ловушку.
# - Произвели подготовку данных для машинного обучения. Разделили на признаки и целевой признак.
# - Разбили данные на три выборки: обучающую, валидационную и тестовую в соотношении 60/20/20.
# - Произвели масштабирование признаков методом стандартизации.
# - В датасете явный дисбаланс в целевом признаке - отрицательны ответов ≈ 80% , положитительных ≈ 20%.

# %% [markdown]
# ## Исследование задачи

# %% [markdown]
# ### Обучение моделей без учёта дисбаланса.

# %% [markdown]
# Перед нами задача классификации «обучения с учителем».
#
# - модель ***Дерево Решений*** - `Decision Tree`
# - модель ***Случайный лес*** - `Random Forest`
# - модель ***Логистическая регрессия*** - `Logistic Regression`

# %% [markdown]
# Модель ***Дерево Решений*** - `Decision Tree`

# %%
# Подберем гиперпараметры:
best_depth = 0
best_leaf = 0
best_accuracy = 0

for depth in range(1,101):
    for leaf in range(1, 10, 2):
        model_dtc = DecisionTreeClassifier(random_state=12345670, max_depth=depth, min_samples_leaf=leaf)
        # обучение модели
        model_dtc.fit(features_train, target_train)
        # предсказание валидационной выборки
        predictions_valid_dtc = model_dtc.predict(features_valid)
        # расчет точности
        accuracy = accuracy_score(target_valid, predictions_valid_dtc)
        if accuracy > best_accuracy:
            best_depth = depth
            best_accuracy = accuracy
            best_leaf = leaf

print('Лучшая глубина дерева -', best_depth,', Мин. кол-во элементов выборки -', best_leaf,', Лучшая точность -', best_accuracy)
# Out:
# Лучшая глубина дерева - 6 , Мин. кол-во элементов выборки - 7 , Лучшая точность - 0.8595

# %% [markdown]
# Модель ***Случайный лес*** - `Random Forest`

# %%
# Подберем гиперпараметры:
best_estim = 0
best_accuracy = 0

for estim in range(1,101):
    model_rfc = RandomForestClassifier(random_state=12345670, n_estimators=estim)
    model_rfc.fit(features_train, target_train)
    predictions_valid_rfс = model_rfc.predict(features_valid)
    accuracy = accuracy_score(target_valid, predictions_valid_rfс)
    if accuracy > best_accuracy:
        best_estim = estim
        best_leaf = leaf
        best_accuracy = accuracy

print('Лучшее количество деревьев -', best_estim,', Лучшая точность -', best_accuracy)
# Out:
# Лучшее количество деревьев - 33 , Лучшая точность - 0.8635

# %% [markdown]
# Модель ***Логистическая регрессия*** - `Logistic Regression`

# %%
model_lgr = LogisticRegression(random_state=12345670, solver='lbfgs')
# обучение модели
model_lgr.fit(features_train, target_train)
# предсказание валидационной выборки
predictions_valid_lgr = model_lgr.predict(features_valid)
# расчет точности
accuracy = accuracy_score(target_valid, predictions_valid_lgr)
print('Лучшая точность -', accuracy)
# Out:
# Лучшая точность - 0.814

# %% [markdown]
# ***Вывод:*** Лучшая модель без усета дисбаланса - ***Случайный лес*** - `Random Forest` - с точностью 0.8635

# %%
# Функция для отображения соотношения ответов моделей (сколько 0, сколько 1)
def all_models_share(features_train, target_train, features_valid, target_valid):
    model_dtc = DecisionTreeClassifier(random_state=12345670, max_depth=6, min_samples_leaf=7)
    model_dtc.fit(features_train, target_train)
    share_dtc = pd.Series(model_dtc.predict(features_valid)).value_counts(normalize = 1)
    
    
    
    model_rfc = RandomForestClassifier(random_state=12345670, n_estimators = 33)
    model_rfc.fit(features_train, target_train)
    share_rfc = pd.Series(model_rfc.predict(features_valid)).value_counts(normalize = 1)
    
    model_lgr = LogisticRegression(random_state=12345670, solver = 'liblinear')
    model_lgr.fit(features_train, target_train)
    share_lgr = pd.Series(model_lgr.predict(features_valid)).value_counts(normalize = 1)
    
  
    print('Доли ответов',
          '\n', 'Дерево решений:', '\n', share_dtc,
          '\n', 'Случайный лес:', '\n', share_rfc,
          '\n', 'Логистческая регрессия:','\n', share_lgr)

# %%
#Применим функцию отображения соотношения ответов моделей
all_models_share(features_train, target_train, features_valid, target_valid)
# Out:
# Доли ответов
#  Дерево решений:
#  0    0.884
# 1    0.116
# dtype: float64
#  Случайный лес:
#  0    0.869
# 1    0.131
# dtype: float64
#  Логистческая регрессия:
#  0    0.9255
# 1    0.0745
# dtype: float64

# %% [markdown]
# Модели с большой вероятностью выдают ответ 0.

# %% [markdown]
# ### Проверим качество моделей без учёта дисбаланса.

# %%
# Создаем функцию для вывода значений матрицы ошибок, recall, precision и F1-меры:
def cm_r_p_f1(target_valid, prediction):
    print('Матрица ошибок:', '\n', confusion_matrix(target_valid, prediction))
    print('Recall:' , recall_score(target_valid, prediction))
    print('Precision:', precision_score(target_valid, prediction))
    print('F1-мера:', f1_score(target_valid, prediction))

# %% [markdown]
# модель ***Дерево Решений*** - `Decision Tree`:

# %%
cm_r_p_f1(target_valid, predictions_valid_dtc)
auc_roc_dtc = roc_auc_score(target_valid,  model_dtc.predict_proba(features_valid)[:, 1])
print('AUC-ROC:', auc_roc_dtc)
# Out:
# Матрица ошибок:
#  [[1452  133]
#  [ 203  212]]
# Recall: 0.5108433734939759
# Precision: 0.6144927536231884
# F1-мера: 0.5578947368421053
# AUC-ROC: 0.7957014176580138

# %% [markdown]
# модель - ***Случайный лес*** - `Random Forest`:

# %%
cm_r_p_f1(target_valid, predictions_valid_rfс)
auc_roc_rfc = roc_auc_score(target_valid,  model_rfc.predict_proba(features_valid)[:, 1])
print('AUC-ROC:', auc_roc_rfc)
# Out:
# Матрица ошибок:
#  [[1525   60]
#  [ 217  198]]
# Recall: 0.4771084337349398
# Precision: 0.7674418604651163
# F1-мера: 0.588410104011887
# AUC-ROC: 0.8583611417277944

# %% [markdown]
# Модель - ***Логистическая регрессия*** - `Logistic Regression`:

# %%
cm_r_p_f1(target_valid, predictions_valid_lgr)
auc_roc_lgr = roc_auc_score(target_valid,  model_lgr.predict_proba(features_valid)[:, 1])
print('AUC-ROC:', auc_roc_lgr)
# Out:
# Матрица ошибок:
#  [[1532   53]
#  [ 319   96]]
# Recall: 0.23132530120481928
# Precision: 0.6442953020134228
# F1-мера: 0.3404255319148936
# AUC-ROC: 0.7735183003306603

# %% [markdown]
# **Построим ROC-кривую для кажддой модели. И выведем показатель AUC-ROC.**

# %%
plt.figure(figsize=[12,9])

plt.plot([0, 1], [0, 1], linestyle='--', label='RandomModel')


fpr, tpr, thresholds = roc_curve(target_valid,  model_dtc.predict_proba(features_valid)[:, 1])
print('AUC-ROC DecisionTreeClassifier:',auc_roc_dtc)
plt.plot(fpr, tpr, label='DecisionTreeClassifier')

fpr, tpr, thresholds = roc_curve(target_valid, model_rfc.predict_proba(features_valid)[:, 1])
print('AUC-ROC RandomForestClassifier:',auc_roc_rfc)
plt.plot(fpr, tpr, label='RandomForestClassifier')

fpr, tpr, thresholds = roc_curve(target_valid, model_lgr.predict_proba(features_valid)[:, 1])
print('AUC-ROC LogisticRegression:',auc_roc_lgr)
plt.plot(fpr, tpr, label='LogisticRegression')


plt.xlim([0,1])
plt.ylim([0,1])

plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")

plt.legend(loc='lower right', fontsize='x-large')

plt.title("ROC-кривая")
plt.show()
# Out:
# AUC-ROC DecisionTreeClassifier: 0.7957014176580138
# AUC-ROC RandomForestClassifier: 0.8583611417277944
# AUC-ROC LogisticRegression: 0.7735183003306603

# %% [markdown]
# ***Вывод:*** во всех трех моделях на валидационной выборке превалируют истинно отрицательные ответы. Все модели имеют recall ниже, чем percision, из-за перекоса данных, что влияет на F1-меру. Без учёта дисбаланса наибольшее значение F1( 0.557 и 0.589) и AUC_ROC(0.796 и 0.858) наблюдается в моделях `Дерево решений` и `Случайный лес` соответственно. Лучшая модель без учета дисбаланса `Случайный лес`.

# %% [markdown]
# ## Борьба с дисбалансом.

# %% [markdown]
# Отрицательных классов в 4 раза больше чем положительных. Необходимо отбалансировать данные. Воспользоваться следующими методами:
#
# - Взвешивание классов (`class_weight` в гиперпараметрах моделей);
# - Увелечение количества положительного класса - `upsampling`;
# - Уменьшение количества отрицательного класса - `downsample`;

# %% [markdown]
# ### Взвешивание классов.

# %%
# Дерево решений:
model_dtc = DecisionTreeClassifier(random_state=12345670, max_depth=6, min_samples_leaf=7, class_weight='balanced')
model_dtc.fit(features_train, target_train)
predictions_valid_dtc = model_dtc.predict(features_valid)
print('Recall:' , recall_score(target_valid, predictions_valid_dtc))
print('Precision:', precision_score(target_valid, predictions_valid_dtc))
print('F1-мера:', f1_score(target_valid, predictions_valid_dtc))
print('AUC-ROC:', roc_auc_score(target_valid,  model_dtc.predict_proba(features_valid)[:, 1]))
# Out:
# Recall: 0.8072289156626506
# Precision: 0.46143250688705234
# F1-мера: 0.5872042068361086
# AUC-ROC: 0.8426962107103493

# %%
# Случайный лес:
model_rfc = RandomForestClassifier(random_state=12345670, n_estimators = 33, class_weight='balanced')
model_rfc.fit(features_train, target_train)
predictions_valid_rfc = model_rfc.predict(features_valid)
print('Recall:' , recall_score(target_valid, predictions_valid_rfc))
print('Precision:', precision_score(target_valid, predictions_valid_rfc))
print('F1-мера:', f1_score(target_valid, predictions_valid_rfc))
print('AUC-ROC:', roc_auc_score(target_valid,  model_rfc.predict_proba(features_valid)[:, 1]))
# Out:
# Recall: 0.45542168674698796
# Precision: 0.7620967741935484
# F1-мера: 0.5701357466063349
# AUC-ROC: 0.8588529512371252

# %%
# Логистическая регрессия:
model_lgr = LogisticRegression(random_state=12345670, solver = 'liblinear', class_weight='balanced')
model_lgr.fit(features_train, target_train)
predictions_valid_lgr = model_lgr.predict(features_valid)
print('Recall:' , recall_score(target_valid, predictions_valid_lgr))
print('Precision:', precision_score(target_valid, predictions_valid_lgr))
print('F1-мера:', f1_score(target_valid, predictions_valid_lgr))
print('AUC-ROC:', roc_auc_score(target_valid,  model_lgr.predict_proba(features_valid)[:, 1]))
# Out:
# Recall: 0.672289156626506
# Precision: 0.4025974025974026
# F1-мера: 0.503610108303249
# AUC-ROC: 0.7775105469195394

# %% [markdown]
# ***Вывод:*** При применении в гиперпараметрах моделей взвешивание классов наибольшее улучшение F1-меры показала модель `Логистической регрессии`(улучшение F1-меры на 0,16). Модель `Дерево решений`: улучшилась F1-мера на 0,03. Модель `Случайный лес`: ухудшилась F1-мера на 0,004. Модели `Дерево решений` и `Логистической регрессии` стараются собрать больше данных, чем показать верную точность (recall > precision). В итоге, можно сказать, что наибольший эффект улучшения от введения в гиперпараметрах моделей взвешивание классов наблюдается в модели `Логистической регрессии`. А лучшей моделью - `Случайный лес` - AUC-ROC: 0.859.

# %% [markdown]
# ### Увелечение количества положительного класса.

# %%
def upsample(features, target, repeat):
    features_zeros = features[target == 0]
    features_ones = features[target == 1]
    target_zeros = target[target == 0]
    target_ones = target[target == 1]
    
    features_upsampled = pd.concat([features_zeros] + [features_ones] * repeat)
    target_upsampled = pd.concat([target_zeros] + [target_ones] * repeat)
    
    features_upsampled, target_upsampled = shuffle(features_upsampled, target_upsampled, random_state=12345)
    
    return features_upsampled, target_upsampled


features_train_upsampled, target_train_upsampled = upsample(features_train, target_train, 4)

# %%
print(target_train_upsampled.value_counts(normalize = 1))
print(target_train_upsampled.shape)
# Out:
# 1    0.506203
# 0    0.493797
# Name: exited, dtype: float64
# (9672,)

# %%
# Дерево решений:
model_dtc_ups = DecisionTreeClassifier(random_state=12345670, max_depth=6, min_samples_leaf=7)
model_dtc_ups.fit(features_train_upsampled, target_train_upsampled)
predictions_valid_dtc_ups = model_dtc_ups.predict(features_valid)
print('Recall:' , recall_score(target_valid, predictions_valid_dtc_ups))
print('Precision:', precision_score(target_valid, predictions_valid_dtc_ups))
print('F1-мера:', f1_score(target_valid, predictions_valid_dtc_ups))
print('AUC-ROC:', roc_auc_score(target_valid,  model_dtc_ups.predict_proba(features_valid)[:, 1]))
# Out:
# Recall: 0.763855421686747
# Precision: 0.4788519637462236
# F1-мера: 0.5886722376973074
# AUC-ROC: 0.841746797917221

# %%
# Случайный лес:
model_rfc_ups = RandomForestClassifier(random_state=12345670, n_estimators = 33)
model_rfc_ups.fit(features_train_upsampled, target_train_upsampled)
predictions_valid_rfc_ups = model_rfc_ups.predict(features_valid)
print('Recall:' , recall_score(target_valid, predictions_valid_rfc_ups))
print('Precision:', precision_score(target_valid, predictions_valid_rfc_ups))
print('F1-мера:', f1_score(target_valid, predictions_valid_rfc_ups))
print('AUC-ROC:', roc_auc_score(target_valid,  model_rfc_ups.predict_proba(features_valid)[:, 1]))
# Out:
# Recall: 0.5325301204819277
# Precision: 0.6597014925373135
# F1-мера: 0.5893333333333334
# AUC-ROC: 0.8436136976929801

# %%
# Логистическая регрессия:
model_lgr_ups = LogisticRegression(random_state=12345670, solver = 'liblinear')
model_lgr_ups.fit(features_train_upsampled, target_train_upsampled)
predictions_valid_lgr_ups = model_lgr_ups.predict(features_valid)
print('Recall:' , recall_score(target_valid, predictions_valid_lgr_ups))
print('Precision:', precision_score(target_valid, predictions_valid_lgr_ups))
print('F1-мера:', f1_score(target_valid, predictions_valid_lgr_ups))
print('AUC-ROC:', roc_auc_score(target_valid,  model_lgr_ups.predict_proba(features_valid)[:, 1]))
# Out:
# Recall: 0.6843373493975904
# Precision: 0.4011299435028249
# F1-мера: 0.5057880676758683
# AUC-ROC: 0.7775090266428489

# %% [markdown]
# **Построим ROC-кривую для кажддой модели. И выведем показатель AUC-ROC.**

# %%
plt.figure(figsize=[12,9])

plt.plot([0, 1], [0, 1], linestyle='--', label='RandomModel')


fpr, tpr, thresholds = roc_curve(target_valid,  model_dtc_ups.predict_proba(features_valid)[:, 1])
print('AUC-ROC DecisionTreeClassifier:',roc_auc_score(target_valid,  model_dtc_ups.predict_proba(features_valid)[:, 1]))
plt.plot(fpr, tpr, label='DecisionTreeClassifier')

fpr, tpr, thresholds = roc_curve(target_valid, model_rfc_ups.predict_proba(features_valid)[:, 1])
print('AUC-ROC RandomForestClassifier:',roc_auc_score(target_valid,  model_rfc_ups.predict_proba(features_valid)[:, 1]))
plt.plot(fpr, tpr, label='RandomForestClassifier')

fpr, tpr, thresholds = roc_curve(target_valid, model_lgr_ups.predict_proba(features_valid)[:, 1])
print('AUC-ROC LogisticRegression:',roc_auc_score(target_valid,  model_lgr_ups.predict_proba(features_valid)[:, 1]))
plt.plot(fpr, tpr, label='LogisticRegression')


plt.xlim([0,1])
plt.ylim([0,1])

plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")

plt.legend(loc='lower right', fontsize='x-large')

plt.title("ROC-кривая")
plt.show()
# Out:
# AUC-ROC DecisionTreeClassifier: 0.841746797917221
# AUC-ROC RandomForestClassifier: 0.8436136976929801
# AUC-ROC LogisticRegression: 0.7775090266428489

# %% [markdown]
# ***Вывод:*** При применении алгоритма `Увелечение количества положительного класса` улучшение F1-меры показали все модели. Модель `Дерево решений`: улучшилась F1-мера на 0,031. Модель `Случайный лес`: улучшилась F1-мера на 0,028. Модель `Логистическая регрессия`: улучшилась F1-мера на 0,16. Модели `Дерево решений и Логистической регрессии` стараются собрать больше данных, чем показать верную точность (recall > precision). В итоге, можно сказать, что наибольший эффект улучшения от применении алгоритма `Увелечение количества положительного класса` наблюдается в модели `Случайный лес` (наибольшии F1-мера:0.589 и AUC-ROC = 0.8436, площадь под ROC-кривой больше).

# %% [markdown]
# ### Уменьшение количества отрицательного класса

# %%
def downsample(features, target, fraction):
    features_zeros = features[target == 0]
    features_ones = features[target == 1]
    target_zeros = target[target == 0]
    target_ones = target[target == 1]

    features_downsampled = pd.concat([features_zeros.sample(frac=fraction, random_state=12345)] + [features_ones])
    target_downsampled = pd.concat([target_zeros.sample(frac=fraction, random_state=12345)] + [target_ones])
    
    features_downsampled, target_downsampled = shuffle(features_downsampled, target_downsampled, random_state=12345)
    
    return features_downsampled, target_downsampled

features_train_downsampled, target_train_downsampled = downsample(features_train, target_train, 0.25)

# %%
print(target_train_downsampled.value_counts(normalize = 0))
print(target_train_downsampled.shape)
# Out:
# 1    1224
# 0    1194
# Name: exited, dtype: int64
# (2418,)

# %%
# Дерево решений:
model_dtc_dwns = DecisionTreeClassifier(random_state=12345670, max_depth=6, min_samples_leaf=7)
model_dtc_dwns.fit(features_train_downsampled, target_train_downsampled)
predictions_valid_dtc_dwns = model_dtc_dwns.predict(features_valid)
print('Recall:' , recall_score(target_valid, predictions_valid_dtc_dwns))
print('Precision:', precision_score(target_valid, predictions_valid_dtc_dwns))
print('F1-мера:', f1_score(target_valid, predictions_valid_dtc_dwns))
print('AUC-ROC:', roc_auc_score(target_valid,  model_dtc_dwns.predict_proba(features_valid)[:, 1]))
# Out:
# Recall: 0.708433734939759
# Precision: 0.5130890052356021
# F1-мера: 0.5951417004048583
# AUC-ROC: 0.8323613697692981

# %%
# Случайный лес:
model_rfc_dwns = RandomForestClassifier(random_state=12345670, n_estimators = 33)
model_rfc_dwns.fit(features_train_downsampled, target_train_downsampled)
predictions_valid_rfc_dwns = model_rfc_dwns.predict(features_valid)
print('Recall:' , recall_score(target_valid, predictions_valid_rfc_dwns))
print('Precision:', precision_score(target_valid, predictions_valid_rfc_dwns))
print('F1-мера:', f1_score(target_valid, predictions_valid_rfc_dwns))
print('AUC-ROC:', roc_auc_score(target_valid,  model_rfc_dwns.predict_proba(features_valid)[:, 1]))
# Out:
# Recall: 0.7301204819277108
# Precision: 0.48635634028892455
# F1-мера: 0.5838150289017341
# AUC-ROC: 0.848033902170195

# %%
# Логистическая регрессия:
model_lgr_dwns = LogisticRegression(random_state=12345670, solver = 'liblinear')
model_lgr_dwns.fit(features_train_downsampled, target_train_downsampled)
predictions_valid_lgr_dwns = model_lgr_dwns.predict(features_valid)
print('Recall:' , recall_score(target_valid, predictions_valid_lgr_dwns))
print('Precision:', precision_score(target_valid, predictions_valid_lgr_dwns))
print('F1-мера:', f1_score(target_valid, predictions_valid_lgr_dwns))
print('AUC-ROC:', roc_auc_score(target_valid,  model_lgr_dwns.predict_proba(features_valid)[:, 1]))
# Out:
# Recall: 0.6843373493975904
# Precision: 0.39831697054698456
# F1-мера: 0.5035460992907801
# AUC-ROC: 0.7764919615369996

# %% [markdown]
# **Построим ROC-кривую для кажддой модели. И выведем показатель AUC-ROC.**

# %%
plt.figure(figsize=[12,9])

plt.plot([0, 1], [0, 1], linestyle='--', label='RandomModel')


fpr, tpr, thresholds = roc_curve(target_valid,  model_dtc_dwns.predict_proba(features_valid)[:, 1])
print('AUC-ROC DecisionTreeClassifier:',roc_auc_score(target_valid,  model_dtc_dwns.predict_proba(features_valid)[:, 1]))
plt.plot(fpr, tpr, label='DecisionTreeClassifier')

fpr, tpr, thresholds = roc_curve(target_valid, model_rfc_dwns.predict_proba(features_valid)[:, 1])
print('AUC-ROC RandomForestClassifier:',roc_auc_score(target_valid,  model_rfc_dwns.predict_proba(features_valid)[:, 1]))
plt.plot(fpr, tpr, label='RandomForestClassifier')

fpr, tpr, thresholds = roc_curve(target_valid, model_lgr_dwns.predict_proba(features_valid)[:, 1])
print('AUC-ROC LogisticRegression:',roc_auc_score(target_valid,  model_lgr_dwns.predict_proba(features_valid)[:, 1]))
plt.plot(fpr, tpr, label='LogisticRegression')


plt.xlim([0,1])
plt.ylim([0,1])

plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")

plt.legend(loc='lower right', fontsize='x-large')

plt.title("ROC-кривая")
plt.show()
# Out:
# AUC-ROC DecisionTreeClassifier: 0.8323613697692981
# AUC-ROC RandomForestClassifier: 0.848033902170195
# AUC-ROC LogisticRegression: 0.7764919615369996

# %% [markdown]
# ***Вывод:*** При применении метода `Уменьшение количества отрицательного класса` улучшение F1-меры относительно рассмотренных методов баллансировки показалa модель `Дерево решений`: улучшилась F1-мера на 0,038. Модели `Случайный лес` и модель `Логистическая регрессия` хоть и показали увелиение метрики F1-меры относительно небаллансированных моделей, оказались хуже чем при использовании метода `Увелечение количества положительного класса`. Все три модели стараются собрать больше данных, чем показать верную точность (recall > precision). В итоге, можно сказать, что наибольший эффект улучшения от применении алгоритма `Уменьшение количества отрицательного класса` наблюдается в модели `Случайный лес` (наибольшии F1-мера:0.584 и AUC-ROC = 0.848, площадь под ROC-кривой больше).

# %% [markdown]
# ### Вывод по баллансировке

# %% [markdown]
# Улучшение качества модели с учетом дисбаланса классов.
# Лучшая модель по показателям F1 и AUC-ROC - `Случайный лес` при использовании `Увелечение количества положительного класса` - `upsampling`:
#
# F1-мера = 0.5893333333333334
# AUC-ROC = 0.8436136976929801

# %% [markdown]
# ## Тестирование модели

# %%
# Объединяю для обучения данные train и valid:
features_train_valid = pd.concat([features_train] + [features_valid])
target_train_valid = pd.concat([target_train] + [target_valid])

# %%
#применяю upsampling к объединенной выборке:
features_upsampled, target_upsampled = upsample(features_train_valid, target_train_valid, 4)

# %%
# Случайный лес:
model_rfc_ups = RandomForestClassifier(random_state=12345670, n_estimators = 33)
model_rfc_ups.fit(features_upsampled, target_upsampled)
predictions_test_rfc_ups = model_rfc_ups.predict(features_test)
accuracy = accuracy_score(target_test, predictions_test_rfc_ups)
print('Точность модели:',accuracy)
print('Recall:' , recall_score(target_test, predictions_test_rfc_ups))
print('Precision:', precision_score(target_test, predictions_test_rfc_ups))
print('F1-мера:', f1_score(target_test, predictions_test_rfc_ups))
print('AUC-ROC:', roc_auc_score(target_test,  model_rfc_ups.predict_proba(features_test)[:, 1]))
# Out:
# Точность модели: 0.8535
# Recall: 0.5879396984924623
# Precision: 0.6446280991735537
# F1-мера: 0.6149802890932983
# AUC-ROC: 0.8362811247247474

# %% [markdown]
# **Проверим модель на адекватность**

# %%
# Создаем константную модель:
target_predict_constant = pd.Series([0]*len(target_test))
target_predict_constant.value_counts()
# Out:
# 0    2000
# dtype: int64

# %%
# Сравним AUC-ROC — единственный параметр подающийся сравнению,
#потому что константная подель содержит только негативные ответы:
print('AUC-ROC константой модели:', roc_auc_score(target_test, target_predict_constant))
print('AUC-ROC финальной модели:', roc_auc_score(target_test, model_rfc.predict_proba(features_test)[:, 1]))
# Out:
# AUC-ROC константой модели: 0.5
# AUC-ROC финальной модели: 0.8397206067792143

# %%
# Проверяем на модели DummyClassifier:
model_dcr = DummyClassifier(strategy='most_frequent', random_state=12345670)
model_dcr.fit(features_upsampled, target_upsampled)
prediction_dcr = model_dcr.predict(features_test)
print('F1-мера:', f1_score(target_test, prediction_dcr))
print('AUC-ROC:', roc_auc_score(target_test,  model_dcr.predict_proba(features_test)[:, 1]))
print('AUC-ROC финальной модели:', roc_auc_score(target_test, model_rfc.predict_proba(features_test)[:, 1]))
# Out:
# F1-мера: 0.33194328607172646
# AUC-ROC: 0.5
# AUC-ROC финальной модели: 0.8397206067792143

# %% [markdown]
# ***Вывод:***
# При проверки модели `Случайный лес` на тестовой выборке были полученны следующие показатели метрики.
# Точность попадания по классам 0.8535. F1-мера: 0.6149. AUC-ROC: 0.836. Задание по достижению метрики F1-мера: 0.59 выполнено. Модель адекватна и лучше константной.

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# - В датасете 12 столбцов и 10000 записей.
# - Перед нами задача классификации «обучения с учителем»
# - Распределение данных:
#    Из графиков:
#     - Кредитный рейтинг обрывается на 850. Возможно это в принципе максимальное значение.
#     - На удивление кол-во недвижемости распределено равномерно.
#     - У многих на балансе 0.
#     Из describe видно:
#     - Кредитная карта есть у 70%.
#     - Доля активных клиентов 51%.
#     - Доля ушедших клиентов в выборке 20%. Явный дисбалланс классов.
# - На корреляционной матрице мы увидели некоторые явные зависимости:
#     - видна сильная корреляция вероятности ухода клиента от его возраста - средний возраст уходящего клиента равен 45 годам, в то время как текущие клиенты имеют средний возраст 35 лет.
#     - у большей части ушедших клиентов был только один банковский продукт, в то время как у текущих клиентов в среднем два активных продукта.
#     - уходящие клиенты являются менее активными.
#     - срок обслуживания клиента, баланс, наличие кредитки, средитная оценка и ожидаемая зарплата почти не влияют на вероятность ухода.
# - Проверили наш датасет на явные дубликаты. дубликатов нет.
# - Проверили наш датасет на пропуски. Пропуски были обнаруженны в столбце `Tenure` и состовили 10%. Заменили все NaN на медианное значение. преобразовали тип данных в int.
# - Удалили столбец `RowNumber`(фактически дублирует нумерацию объектов с шагом 1) и столбца CustomerId(случайный или последовательный номер, который никак не зависит от действий клиента), а также от столбца Surname(имя клиента, признак невлияющий на уход клиента).
# - Привели наименование столбцов в соответствие с PEP8.
# - Перевели категориальные данные в численные (столбцы `Geography`,`Gender`) методом OHE, что позволит нам использовать разные модели и учесть дамми ловушку.
# - Произвели подготовку данных для машинного обучения. Разделили на признаки и целевой признак.
# - Разбили данные на три выборки: обучающую, валидационную и тестовую в соотношении 60/20/20.
# - Произвели масштабирование признаков методом стандартизации.
# - В датасете явный дисбаланс в целевом признаке - отрицательны ответов ≈ 80% , положитительных ≈ 20%.
# - Провели обучение моделей без учёта дисбаланса.
#     - модель ***Дерево Решений*** - `Decision Tree`
#     - модель ***Случайный лес*** - `Random Forest`
#     - модель ***Логистическая регрессия*** - `Logistic Regression`
#     Лучшая модель - Случайный лес - Random Forest - с точностью 0.8635
#     Модели с большой вероятностью выдают ответ 0.
# - Проверим качество моделей без учёта дисбаланса. Изучили метрики качества для моделей( матрицу ошибок, recall, precision, F1-мера, AUC-ROC). Построили ROC-кривые для всех трех моделей. Во всех трех моделях на валидационной выборке превалируют истинно отрицательные ответы. Все модели имеют recall ниже, чем percision, из-за перекоса данных, что влияет на F1-меру. Без учёта дисбаланса наибольшее значение F1( 0.557 и 0.589) и AUC_ROC(0.796 и 0.858) наблюдается в моделях `Дерево решений` и `Случайный лес` соответственно.
# - Отрицательных классов в 4 раза больше, чем положительных. Для балансирования данные использовали следующими методами:
#     - Взвешивание классов (`class_weight` в гиперпараметрах моделей);
#     При применении в гиперпараметрах моделей взвешивание классов наибольшее улучшение F1-меры показала модель Логистической регрессии(улучшение F1-меры на 0,16). Модель `Дерево решений`: улучшилась F1-мера на 0,03. Модель Случайный лес: ухудшилась F1-мера на 0,004. Модели `Дерево решений` и `Логистической регрессии` стараются собрать больше данных, чем показать верную точность (recall > precision). В итоге, можно сказать, что наибольший эффект улучшения от введения в гиперпараметрах моделей взвешивание классов наблюдается в модели `Логистической регрессии`. А лучшей моделью - `Случайный лес` - AUC-ROC: 0.859.
#     - Увелечение количества положительного класса - `upsampling`;
#     При применении алгоритма `Увелечение количества положительного класса` улучшение F1-меры показали все модели. Модель `Дерево решений`: улучшилась F1-мера на 0,031. Модель `Случайный лес`: улучшилась F1-мера на 0,028. Модель `Логистическая регрессия`: улучшилась F1-мера на 0,16. Модели `Дерево решений и Логистической регрессии` стараются собрать больше данных, чем показать верную точность (recall > precision). В итоге, можно сказать, что наибольший эффект улучшения от применении алгоритма `Увелечение количества положительного класса` наблюдается в модели `Случайный лес` (наибольшии F1-мера:0.589 и AUC-ROC = 0.8436, площадь под ROC-кривой больше).
#     - Уменьшение количества отрицательного класса - `downsample`;
#     При применении метода `Уменьшение количества отрицательного класса` улучшение F1-меры относительно рассмотренных методов баллансировки показалa модель Дерево решений: улучшилась F1-мера на 0,038. Модели `Случайный лес` и модель `Логистическая регрессия` хоть и показали увелиение метрики F1-меры относительно небаллансированных моделей, оказались хуже чем при использовании метода `Увелечение количества положительного класса`. Все три модели стараются собрать больше данных, чем показать верную точность (recall > precision). В итоге, можно сказать, что наибольший эффект улучшения от применении алгоритма `Уменьшение количества отрицательного класса` наблюдается в модели `Случайный лес` (наибольшии F1-мера:0.584 и AUC-ROC = 0.848, площадь под ROC-кривой больше).
#     - Построили ROC-кривые моделей для каждого из методов.
#     - По итогу исследования была выбранна модель `Случайный лес` улучшенная методом `upsampling`:
#         - Recall: 0.5325301204819277
#         - Precision: 0.6597014925373135
#         - F1-мера = 0.5893333333333334
#         - AUC-ROC = 0.8436136976929801
# - Провели тестирование модели предварительно обучив ее на объединенной выборке(train и valid).
#     - Полученны следующие показатели метрики:
#         - Точность попадания по классам 0.8535.
#         - Recall: 0.5879396984924623
#         - Precision: 0.6446280991735537
#         - F1-мера: 0.6149
#         - AUC-ROC: 0.836
#     - Модель адекватна и лучше константной (Значение AUC-ROC выше 0.5).
# - Задание по достижению метрики F1-мера: 0.59 - выполнено.

# %% [markdown]
# ## Чек-лист готовности проекта

# %% [markdown]
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  Jupyter Notebook открыт
# - [x]  Весь код выполняется без ошибок
# - [x]  Ячейки с кодом расположены в порядке исполнения
# - [x]  Выполнен шаг 1: данные подготовлены
# - [x]  Выполнен шаг 2: задача исследована
#     - [x]  Исследован баланс классов
#     - [x]  Изучены модели без учёта дисбаланса
#     - [x]  Написаны выводы по результатам исследования
# - [x]  Выполнен шаг 3: учтён дисбаланс
#     - [x]  Применено несколько способов борьбы с дисбалансом
#     - [x]  Написаны выводы по результатам исследования
# - [x]  Выполнен шаг 4: проведено тестирование
# - [x]  Удалось достичь *F1*-меры не менее 0.59
# - [x]  Исследована метрика *AUC-ROC*
